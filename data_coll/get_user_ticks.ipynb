# %% [markdown]
# This notebook is used to call the get-ticks api on Mountain Project using a list of user ids. The ticks are the routes that the user has climbed.

# %%
from pymongo import MongoClient
import json, re, requests, pprint, urllib, time
from bs4 import BeautifulSoup
from mp_api import MP
import numpy as np
import pandas as pd
# %load_ext autoreload
# %autoreload 2

# %%
key_path = '../data/mp_api_key.txt'
with open(key_path, 'r') as key_text:
    key = key_text.read()

# %%
users_path = '../data/user_ids.txt'
with open(users_path, 'r') as users_text:
    users = users_text.read().splitlines()

# %%
client = MongoClient('localhost', 27017)
db = 'mountain_project'
collection = 'user_ticks'
if collection in client[db].list_collection_names():
    (client[db])[collection].drop()

user_db = MP(key, client, db, collection)

for user in users:
    user_db.api_get_ticks(user)

# %%
pprint.pprint(user_db.collection.find_one())
# Out:
# {'_id': ObjectId('5e8cbe454f58497fe2df7686'),
#  'ticks': [{'date': '2019-11-26',
#             'leadStyle': 'Fell/Hung',
#             'notes': 'Hang dogging. Didn’t try past 3rd bolt. ',
#             'pitches': 1,
#             'routeId': 105944680,
#             'style': 'Lead',
#             'tickId': 118096538,
#             'userRating': '5.11c',
#             'userStars': 2},
#            {'date': '2019-11-26',
#             'leadStyle': 'Fell/Hung',
#             'notes': 'Felt too pumped between 3rd and 4th bolt. Took a bunch '
#                      'of practice falls',
#             'pitches': 1,
#             'routeId': 105944620,
#             'style': 'Lead',
#             'tickId': 118096536,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-11-24',
#             'leadStyle': 'Onsight',
#             'notes': 'I led P2,4. We rapped after P5',
#             'pitches': 5,
#             'routeId': 105732278,
#             'style': 'Lead',
#             'tickId': 118086850,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2019-11-22',
#             'leadStyle': '',
#             'notes': 'Clean. Stay right to first bolt, then left',
#             'pitches': 1,
#             'routeId': 114153008,
#             'style': 'TR',
#             'tickId': 118078616,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-11-22',
#             'leadStyle': 'Redpoint',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 116212197,
#             'style': 'Lead',
#             'tickId': 118078615,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-11-22',
#             'leadStyle': '',
#             'notes': 'Clean. Practiced crux at first bolt',
#             'pitches': 1,
#             'routeId': 116212197,
#             'style': 'TR',
#             'tickId': 118078614,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-11-22',
#             'leadStyle': 'Redpoint',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 107554697,
#             'style': 'Lead',
#             'tickId': 118078329,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-11-22',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 107554706,
#             'style': 'Lead',
#             'tickId': 118078327,
#             'userRating': '5.8',
#             'userStars': 2},
#            {'date': '2019-11-22',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 108315715,
#             'style': 'Lead',
#             'tickId': 118078193,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-11-17',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 107430182,
#             'style': 'Solo',
#             'tickId': 118061215,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-11-17',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105918869,
#             'style': 'Lead',
#             'tickId': 118060047,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-11-17',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105826083,
#             'style': 'Lead',
#             'tickId': 118060044,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-11-17',
#             'leadStyle': '',
#             'notes': 'Clean',
#             'pitches': 1,
#             'routeId': 105820173,
#             'style': 'TR',
#             'tickId': 118060042,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-11-17',
#             'leadStyle': '',
#             'notes': 'Hung multiple times',
#             'pitches': 1,
#             'routeId': 105927469,
#             'style': 'TR',
#             'tickId': 118060040,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-11-15',
#             'leadStyle': 'Fell/Hung',
#             'notes': 'Clean until past 2nd bolt. Then took at 3rd and 4th '
#                      'bolts a couple times to find the moves.',
#             'pitches': 1,
#             'routeId': 105820098,
#             'style': 'Lead',
#             'tickId': 118048088,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2019-11-15',
#             'leadStyle': 'Fell/Hung',
#             'notes': 'One-hung. Clean until I grabbed the draw and hung at 4th '
#                      '(last) bolt. ',
#             'pitches': 1,
#             'routeId': 105944620,
#             'style': 'Lead',
#             'tickId': 118048084,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-11-15',
#             'leadStyle': 'Redpoint',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105819734,
#             'style': 'Lead',
#             'tickId': 118048080,
#             'userRating': '5.9',
#             'userStars': 2},
#            {'date': '2019-11-15',
#             'leadStyle': 'Redpoint',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105944541,
#             'style': 'Lead',
#             'tickId': 118048079,
#             'userRating': '5.10a',
#             'userStars': 2},
#            {'date': '2019-11-15',
#             'leadStyle': 'Redpoint',
#             'notes': 'Finally sent! ',
#             'pitches': 1,
#             'routeId': 105944445,
#             'style': 'Lead',
#             'tickId': 118048077,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-11-15',
#             'leadStyle': 'Fell/Hung',
#             'notes': 'Sailed through crux between bolts 3-4. Fell at bolt 6, '
#                      'too pumped. ',
#             'pitches': 1,
#             'routeId': 105944445,
#             'style': 'Lead',
#             'tickId': 118048076,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-11-13',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 106650919,
#             'style': 'Solo',
#             'tickId': 118041831,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-11-13',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 106650925,
#             'style': 'Solo',
#             'tickId': 118041830,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2019-11-11',
#             'leadStyle': 'Onsight',
#             'notes': 'Led P1,3,5.',
#             'pitches': 6,
#             'routeId': 105821892,
#             'style': 'Lead',
#             'tickId': 118033541,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-11-09',
#             'leadStyle': '',
#             'notes': 'Clean, but very pumped at the top. Reachy :(',
#             'pitches': 1,
#             'routeId': 108781019,
#             'style': 'TR',
#             'tickId': 118014897,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-11-09',
#             'leadStyle': 'Onsight',
#             'notes': 'First 11a!',
#             'pitches': 1,
#             'routeId': 105942220,
#             'style': 'Lead',
#             'tickId': 118014891,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-11-09',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105942208,
#             'style': 'Lead',
#             'tickId': 118014888,
#             'userRating': '5.10b',
#             'userStars': 4},
#            {'date': '2019-11-09',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 2,
#             'routeId': 106776797,
#             'style': 'Lead',
#             'tickId': 118014887,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-11-09',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 108128281,
#             'style': 'Lead',
#             'tickId': 118014872,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-11-08',
#             'leadStyle': '',
#             'notes': 'Clean',
#             'pitches': 1,
#             'routeId': 105819734,
#             'style': 'TR',
#             'tickId': 118009260,
#             'userRating': '5.9',
#             'userStars': 2},
#            {'date': '2019-11-08',
#             'leadStyle': '',
#             'notes': 'Clean',
#             'pitches': 1,
#             'routeId': 105944650,
#             'style': 'TR',
#             'tickId': 118009257,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-11-08',
#             'leadStyle': '',
#             'notes': 'Flailed about a bit to remember the beta',
#             'pitches': 1,
#             'routeId': 107556606,
#             'style': 'TR',
#             'tickId': 118009256,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-11-08',
#             'leadStyle': '',
#             'notes': 'Rested at 2nd bolt, sent the rest clean!',
#             'pitches': 1,
#             'routeId': 107556606,
#             'style': 'TR',
#             'tickId': 118009255,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-11-08',
#             'leadStyle': '',
#             'notes': 'Hung at every bolt',
#             'pitches': 1,
#             'routeId': 105944620,
#             'style': 'TR',
#             'tickId': 118009251,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-11-03',
#             'leadStyle': '',
#             'notes': 'Clean. Cold. ',
#             'pitches': 1,
#             'routeId': 105740996,
#             'style': 'Follow',
#             'tickId': 117988289,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2019-08-31',
#             'leadStyle': '',
#             'notes': 'Lapped it again :)',
#             'pitches': 1,
#             'routeId': 105941644,
#             'style': 'TR',
#             'tickId': 117673381,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2019-08-31',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105941644,
#             'style': 'Lead',
#             'tickId': 117673380,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2019-08-31',
#             'leadStyle': 'Onsight',
#             'notes': 'Led P1, 3, 6.\r\n'
#                      'P1: #3, .75 (or #2/#1). P2: 4 small pieces. P3: bolts, '
#                      'P4: bolts #1. P5: #2, P6: bolts',
#             'pitches': 6,
#             'routeId': 108321854,
#             'style': 'Lead',
#             'tickId': 117673329,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-08-31',
#             'leadStyle': 'Fell/Hung',
#             'notes': 'Jason had placed #1, #3. I placed .75, #2, #3, #3. Hung '
#                      'on first #3, and #2',
#             'pitches': 1,
#             'routeId': 106536533,
#             'style': 'Lead',
#             'tickId': 117669112,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-08-30',
#             'leadStyle': 'Redpoint',
#             'notes': 'Sent!!! Placed metolius .1, BD nut #4, BD nut #5, '
#                      'metolius .2 in the hard section',
#             'pitches': 1,
#             'routeId': 105808602,
#             'style': 'Lead',
#             'tickId': 117669116,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2019-08-30',
#             'leadStyle': '',
#             'notes': 'Figured out the gear and moves',
#             'pitches': 1,
#             'routeId': 105808602,
#             'style': 'TR',
#             'tickId': 117669115,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2019-08-30',
#             'leadStyle': '',
#             'notes': 'Sent!',
#             'pitches': 1,
#             'routeId': 105808602,
#             'style': 'TR',
#             'tickId': 117669114,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2019-08-30',
#             'leadStyle': 'Onsight',
#             'notes': 'Pumped out my calves and went for it',
#             'pitches': 1,
#             'routeId': 105948657,
#             'style': 'Lead',
#             'tickId': 117669113,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-08-30',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105934194,
#             'style': 'Follow',
#             'tickId': 117669111,
#             'userRating': '5.9',
#             'userStars': 4},
#            {'date': '2019-08-04',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 115679376,
#             'style': 'Follow',
#             'tickId': 117551236,
#             'userRating': '5.8',
#             'userStars': 3},
#            {'date': '2019-08-04',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 114561844,
#             'style': 'Follow',
#             'tickId': 117551235,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-08-04',
#             'leadStyle': 'Onsight',
#             'notes': 'Led all pitches. Amazing crack! ',
#             'pitches': 3,
#             'routeId': 106776367,
#             'style': 'Lead',
#             'tickId': 117551234,
#             'userRating': '5.9',
#             'userStars': 3},
#            {'date': '2019-08-04',
#             'leadStyle': '',
#             'notes': 'Jason led in 1 pitch. 13 min',
#             'pitches': 1,
#             'routeId': 107577227,
#             'style': 'Follow',
#             'tickId': 117551231,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-08-04',
#             'leadStyle': 'Redpoint',
#             'notes': 'I led. Simuled in one pitch. ',
#             'pitches': 1,
#             'routeId': 107577227,
#             'style': 'Lead',
#             'tickId': 117551230,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-08-03',
#             'leadStyle': '',
#             'notes': 'Follow in 1 pitch',
#             'pitches': 1,
#             'routeId': 106621379,
#             'style': 'Follow',
#             'tickId': 117551237,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-08-03',
#             'leadStyle': 'Onsight',
#             'notes': 'Linked P1-2, P3-4 (with simul), P5-6, P8-9 (with '
#                      'simul).\n'
#                      'I led 3-4, 7.',
#             'pitches': 5,
#             'routeId': 113441195,
#             'style': 'Lead',
#             'tickId': 117551233,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2019-08-03',
#             'leadStyle': 'Fell/Hung',
#             'notes': 'Linked 1-2, 3-4. I led 3-4, 6. P6 was the 10c and I took '
#                      'a bunch to rest and test gear but sent all the moves. ',
#             'pitches': 5,
#             'routeId': 106072248,
#             'style': 'Lead',
#             'tickId': 117551232,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-08-03',
#             'leadStyle': '',
#             'notes': 'Jason led in 1 simul. 27 minutes',
#             'pitches': 1,
#             'routeId': 105934199,
#             'style': 'Follow',
#             'tickId': 117551229,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2019-07-28',
#             'leadStyle': 'Redpoint',
#             'notes': 'Led P2. Soloed P4. ',
#             'pitches': 3,
#             'routeId': 105797867,
#             'style': 'Lead',
#             'tickId': 117518237,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2019-07-21',
#             'leadStyle': '',
#             'notes': 'Midnight climb',
#             'pitches': 1,
#             'routeId': 107577227,
#             'style': 'Follow',
#             'tickId': 117386094,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-07-21',
#             'leadStyle': '',
#             'notes': 'Midnight climb',
#             'pitches': 4,
#             'routeId': 105934199,
#             'style': 'Follow',
#             'tickId': 117386093,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2019-07-20',
#             'leadStyle': 'Onsight',
#             'notes': 'Dirty',
#             'pitches': 1,
#             'routeId': 114797471,
#             'style': 'Lead',
#             'tickId': 117386104,
#             'userRating': '',
#             'userStars': 1},
#            {'date': '2019-07-20',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 106728476,
#             'style': 'Lead',
#             'tickId': 117386103,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-07-20',
#             'leadStyle': 'Onsight',
#             'notes': 'Only had a bit more than a single rack and would have '
#                      'preferred a bit more',
#             'pitches': 1,
#             'routeId': 106842554,
#             'style': 'Lead',
#             'tickId': 117386101,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-07-20',
#             'leadStyle': '',
#             'notes': 'In alpine slippers again!',
#             'pitches': 1,
#             'routeId': 107533380,
#             'style': 'Follow',
#             'tickId': 117386100,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-07-20',
#             'leadStyle': '',
#             'notes': 'In alpine slippers!',
#             'pitches': 1,
#             'routeId': 107533380,
#             'style': 'Follow',
#             'tickId': 117386099,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-07-20',
#             'leadStyle': 'Redpoint',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 107533380,
#             'style': 'Lead',
#             'tickId': 117386098,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-07-20',
#             'leadStyle': 'Redpoint',
#             'notes': 'Last move on two crappy pieces felt spicy',
#             'pitches': 1,
#             'routeId': 106728460,
#             'style': 'Lead',
#             'tickId': 117386097,
#             'userRating': '5.9',
#             'userStars': 3},
#            {'date': '2019-07-20',
#             'leadStyle': 'Redpoint',
#             'notes': 'So good!',
#             'pitches': 1,
#             'routeId': 106728424,
#             'style': 'Lead',
#             'tickId': 117386096,
#             'userRating': '5.7',
#             'userStars': 4},
#            {'date': '2019-07-20',
#             'leadStyle': 'Redpoint',
#             'notes': 'First move and last move are the hardest',
#             'pitches': 1,
#             'routeId': 106508167,
#             'style': 'Lead',
#             'tickId': 117386095,
#             'userRating': '5.8',
#             'userStars': 3},
#            {'date': '2019-07-20',
#             'leadStyle': 'Redpoint',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105963366,
#             'style': 'Lead',
#             'tickId': 117386092,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2019-07-19',
#             'leadStyle': 'Onsight',
#             'notes': 'Led P1, P3-4. Jason led P5 and it felt hard. My guess is '
#                      '5.10b',
#             'pitches': 4,
#             'routeId': 116839104,
#             'style': 'Lead',
#             'tickId': 117386102,
#             'userRating': '5.10b',
#             'userStars': 4},
#            {'date': '2019-07-19',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 115679309,
#             'style': 'Lead',
#             'tickId': 117378222,
#             'userRating': '5.8',
#             'userStars': 2},
#            {'date': '2019-07-19',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 115679326,
#             'style': 'Lead',
#             'tickId': 117378220,
#             'userRating': '5.7',
#             'userStars': 2},
#            {'date': '2019-07-19',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 115679391,
#             'style': 'Lead',
#             'tickId': 117378215,
#             'userRating': '5.7',
#             'userStars': 2},
#            {'date': '2019-07-19',
#             'leadStyle': '',
#             'notes': 'Soloed just up and down the cracks',
#             'pitches': 1,
#             'routeId': 115679376,
#             'style': 'Solo',
#             'tickId': 117378214,
#             'userRating': '5.8',
#             'userStars': 3},
#            {'date': '2019-07-19',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 115679376,
#             'style': 'Lead',
#             'tickId': 117378207,
#             'userRating': '5.8',
#             'userStars': 3},
#            {'date': '2019-07-19',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 115679357,
#             'style': 'Lead',
#             'tickId': 117378203,
#             'userRating': '5.10a',
#             'userStars': 2},
#            {'date': '2019-07-19',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 114585611,
#             'style': 'Lead',
#             'tickId': 117378184,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-07-19',
#             'leadStyle': '',
#             'notes': 'Stopped at the top of the crack',
#             'pitches': 1,
#             'routeId': 114561844,
#             'style': 'Solo',
#             'tickId': 117378183,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-07-19',
#             'leadStyle': 'Onsight',
#             'notes': 'Placed 1,2,3 and a sling. Could have used another 3 or 4',
#             'pitches': 1,
#             'routeId': 114369760,
#             'style': 'Lead',
#             'tickId': 117378182,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-07-19',
#             'leadStyle': 'Onsight',
#             'notes': 'Placed only .5,1,2,3.  Could have used another 3 or a 4',
#             'pitches': 2,
#             'routeId': 114369871,
#             'style': 'Lead',
#             'tickId': 117378181,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-07-19',
#             'leadStyle': 'Onsight',
#             'notes': 'SR .4 to 4. The #4 would help the insecure leader. A '
#                      'second #3 would be almost as good. ',
#             'pitches': 1,
#             'routeId': 114369793,
#             'style': 'Lead',
#             'tickId': 117378180,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-07-14',
#             'leadStyle': '',
#             'notes': 'Followed ACC student who led in 1 simul pitch. Followed '
#                      'on downclimb as well, more like soloing',
#             'pitches': 1,
#             'routeId': 106378815,
#             'style': 'Follow',
#             'tickId': 117362994,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-07-13',
#             'leadStyle': 'Onsight',
#             'notes': 'Led P1, P4 (with students)',
#             'pitches': 4,
#             'routeId': 106509842,
#             'style': 'Lead',
#             'tickId': 117352981,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-05-24',
#             'leadStyle': '',
#             'notes': 'Clean. Crux around 2nd - 3rd bolt',
#             'pitches': 1,
#             'routeId': 105803971,
#             'style': 'TR',
#             'tickId': 117015219,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-05-24',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105804164,
#             'style': 'Lead',
#             'tickId': 117015216,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-05-24',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105803921,
#             'style': 'Lead',
#             'tickId': 117015212,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2019-05-23',
#             'leadStyle': '',
#             'notes': 'Did it as a stand-start',
#             'pitches': 1,
#             'routeId': 114000041,
#             'style': 'Flash',
#             'tickId': 117010596,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-05-23',
#             'leadStyle': 'Flash',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 108315725,
#             'style': 'Lead',
#             'tickId': 117010574,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-05-23',
#             'leadStyle': 'Flash',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 107554697,
#             'style': 'Lead',
#             'tickId': 117010570,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-05-23',
#             'leadStyle': '',
#             'notes': 'Clean. Cruxy move getting out of the roof',
#             'pitches': 1,
#             'routeId': 116212197,
#             'style': 'TR',
#             'tickId': 117010568,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-05-23',
#             'leadStyle': '',
#             'notes': 'Multiple hangs, but got all the moves!',
#             'pitches': 1,
#             'routeId': 116545302,
#             'style': 'TR',
#             'tickId': 117010565,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-05-23',
#             'leadStyle': '',
#             'notes': 'Multiple hangs, but got all the moves!',
#             'pitches': 1,
#             'routeId': 116545302,
#             'style': 'TR',
#             'tickId': 117010564,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-05-21',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 110174761,
#             'style': 'Flash',
#             'tickId': 117010603,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-05-21',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 110174755,
#             'style': 'Send',
#             'tickId': 117010601,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-05-21',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 3,
#             'routeId': 106657484,
#             'style': 'Attempt',
#             'tickId': 117010598,
#             'userRating': '',
#             'userStars': -1},
#            {'date': '2019-05-21',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 108731202,
#             'style': 'Flash',
#             'tickId': 117010591,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2019-05-21',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 107849034,
#             'style': 'Flash',
#             'tickId': 117010584,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-05-21',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 2,
#             'routeId': 107074342,
#             'style': 'Attempt',
#             'tickId': 117010581,
#             'userRating': '',
#             'userStars': -1},
#            {'date': '2019-05-21',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 106657521,
#             'style': 'Flash',
#             'tickId': 117010579,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2019-01-04',
#             'leadStyle': '',
#             'notes': 'Fell 3 times. ',
#             'pitches': 1,
#             'routeId': 106967911,
#             'style': 'TR',
#             'tickId': 116240546,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2019-01-04',
#             'leadStyle': '',
#             'notes': 'Fell once on the initial steep section. Going left '
#                      'instead of right at 2nd bolt was better.',
#             'pitches': 1,
#             'routeId': 116240483,
#             'style': 'TR',
#             'tickId': 116240543,
#             'userRating': '5.10d, R',
#             'userStars': 2},
#            {'date': '2019-01-04',
#             'leadStyle': '',
#             'notes': 'Clean. Crux for me was pulling the &#34;roof&#34;',
#             'pitches': 1,
#             'routeId': 116240525,
#             'style': 'TR',
#             'tickId': 116240541,
#             'userRating': '5.10c, R',
#             'userStars': 2},
#            {'date': '2018-12-30',
#             'leadStyle': 'Onsight',
#             'notes': 'Did this in four pitches - three ~30m pitches and one '
#                      '~50m? one.\r\n'
#                      'Led P2-3',
#             'pitches': 3,
#             'routeId': 105793305,
#             'style': 'Lead',
#             'tickId': 116225025,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2018-12-21',
#             'leadStyle': 'Fell/Hung',
#             'notes': 'One-hung: clean to fourth bolt, rested, then clean to '
#                      'the anchors. ',
#             'pitches': 1,
#             'routeId': 108441936,
#             'style': 'Lead',
#             'tickId': 116202836,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-12-21',
#             'leadStyle': 'Fell/Hung',
#             'notes': 'Clean to the third bolt, then hung at every bolt. I felt '
#                      'like the moves between the third and fourth bolts were '
#                      'most confusing, and I wasted time and energy and then '
#                      'was a bit pumped for the juggy moves to the end',
#             'pitches': 1,
#             'routeId': 108441936,
#             'style': 'Lead',
#             'tickId': 116202830,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-12-21',
#             'leadStyle': '',
#             'notes': 'Just worked the moves on the bottom half. Figured out a '
#                      'nice sequence through the undercling. ',
#             'pitches': 1,
#             'routeId': 112295303,
#             'style': 'TR',
#             'tickId': 116202828,
#             'userRating': '',
#             'userStars': -1},
#            {'date': '2018-12-17',
#             'leadStyle': '',
#             'notes': 'Lots of takes. Pumpy. ',
#             'pitches': 1,
#             'routeId': 105975216,
#             'style': 'TR',
#             'tickId': 116192236,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2018-12-17',
#             'leadStyle': 'Redpoint',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105732560,
#             'style': 'Lead',
#             'tickId': 116192234,
#             'userRating': '5.10a',
#             'userStars': 3},
#            {'date': '2018-12-17',
#             'leadStyle': 'Redpoint',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105732557,
#             'style': 'Lead',
#             'tickId': 116192233,
#             'userRating': '5.9-',
#             'userStars': 3},
#            {'date': '2018-12-17',
#             'leadStyle': '',
#             'notes': 'Too pumped - one take',
#             'pitches': 1,
#             'routeId': 105732914,
#             'style': 'TR',
#             'tickId': 116192232,
#             'userRating': '5.10d',
#             'userStars': 3},
#            {'date': '2018-12-17',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105732914,
#             'style': 'TR',
#             'tickId': 116192230,
#             'userRating': '5.10d',
#             'userStars': 3},
#            {'date': '2018-12-17',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 109928754,
#             'style': 'TR',
#             'tickId': 116192229,
#             'userRating': '5.8',
#             'userStars': 3},
#            {'date': '2018-12-17',
#             'leadStyle': 'Redpoint',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 109928754,
#             'style': 'Lead',
#             'tickId': 116192228,
#             'userRating': '5.8',
#             'userStars': 3},
#            {'date': '2018-12-16',
#             'leadStyle': '',
#             'notes': 'Tagged along with Ellie and Dylan',
#             'pitches': 5,
#             'routeId': 105836970,
#             'style': 'Follow',
#             'tickId': 116189091,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-12-09',
#             'leadStyle': '',
#             'notes': 'Took twice',
#             'pitches': 1,
#             'routeId': 105891241,
#             'style': 'Follow',
#             'tickId': 116172593,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-12-09',
#             'leadStyle': 'Fell/Hung',
#             'notes': 'Took at the last bolt. Pulled on the draws in the '
#                      'anchor. Felt pumped and scared',
#             'pitches': 1,
#             'routeId': 106104441,
#             'style': 'Lead',
#             'tickId': 116172587,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-12-09',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105884599,
#             'style': 'Lead',
#             'tickId': 116172584,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-12-09',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105884605,
#             'style': 'Lead',
#             'tickId': 116172583,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-12-02',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105903232,
#             'style': 'Lead',
#             'tickId': 116157319,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-12-02',
#             'leadStyle': '',
#             'notes': 'Clean',
#             'pitches': 1,
#             'routeId': 105732320,
#             'style': 'Follow',
#             'tickId': 116157312,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-11-23',
#             'leadStyle': '',
#             'notes': 'A few attempts',
#             'pitches': 1,
#             'routeId': 106640283,
#             'style': '',
#             'tickId': 116128510,
#             'userRating': '',
#             'userStars': -1},
#            {'date': '2018-11-23',
#             'leadStyle': '',
#             'notes': 'Sent second half only',
#             'pitches': 1,
#             'routeId': 106639725,
#             'style': '',
#             'tickId': 116128505,
#             'userRating': '',
#             'userStars': -1},
#            {'date': '2018-11-23',
#             'leadStyle': '',
#             'notes': 'Many attempts, no sends',
#             'pitches': 1,
#             'routeId': 109152569,
#             'style': '',
#             'tickId': 116128501,
#             'userRating': '',
#             'userStars': -1},
#            {'date': '2018-11-23',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 106639718,
#             'style': 'Solo',
#             'tickId': 116128493,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2018-11-23',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 106639709,
#             'style': 'Solo',
#             'tickId': 116128489,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-11-23',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 106640182,
#             'style': 'Solo',
#             'tickId': 116128485,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2018-11-17',
#             'leadStyle': '',
#             'notes': 'Clean',
#             'pitches': 1,
#             'routeId': 105860888,
#             'style': 'TR',
#             'tickId': 116109790,
#             'userRating': '5.10a',
#             'userStars': 3},
#            {'date': '2018-11-17',
#             'leadStyle': 'Fell/Hung',
#             'notes': 'Hung once',
#             'pitches': 1,
#             'routeId': 105860888,
#             'style': 'Lead',
#             'tickId': 116109789,
#             'userRating': '5.10a',
#             'userStars': 3},
#            {'date': '2018-11-17',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105860897,
#             'style': 'TR',
#             'tickId': 116109788,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2018-11-17',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105860897,
#             'style': 'Lead',
#             'tickId': 116109787,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2018-11-17',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 106893722,
#             'style': 'TR',
#             'tickId': 116109786,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2018-11-17',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 106893722,
#             'style': 'Lead',
#             'tickId': 116109785,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2018-11-17',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105860904,
#             'style': 'TR',
#             'tickId': 116109784,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-11-17',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105860904,
#             'style': 'Lead',
#             'tickId': 116109783,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-11-16',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105940826,
#             'style': 'Follow',
#             'tickId': 116103126,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2018-11-16',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105940820,
#             'style': 'TR',
#             'tickId': 116103125,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2018-11-16',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105940820,
#             'style': 'Lead',
#             'tickId': 116103123,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2018-11-16',
#             'leadStyle': 'Redpoint',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105940830,
#             'style': 'Lead',
#             'tickId': 116103122,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2018-11-16',
#             'leadStyle': '',
#             'notes': 'Clean, in approach shoes',
#             'pitches': 1,
#             'routeId': 105940830,
#             'style': 'TR',
#             'tickId': 116103121,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2018-11-11',
#             'leadStyle': '',
#             'notes': 'Clean',
#             'pitches': 1,
#             'routeId': 105940688,
#             'style': 'TR',
#             'tickId': 116101172,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-11-11',
#             'leadStyle': '',
#             'notes': 'In big puff and approach shoes. Not clean',
#             'pitches': 1,
#             'routeId': 105940693,
#             'style': 'TR',
#             'tickId': 116101171,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-09-28',
#             'leadStyle': '',
#             'notes': 'Clean',
#             'pitches': 1,
#             'routeId': 108214806,
#             'style': 'Follow',
#             'tickId': 115369336,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2018-09-28',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 106428241,
#             'style': 'Lead',
#             'tickId': 115369335,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-09-28',
#             'leadStyle': '',
#             'notes': 'Clean!',
#             'pitches': 1,
#             'routeId': 112006571,
#             'style': 'TR',
#             'tickId': 115369334,
#             'userRating': '5.11a',
#             'userStars': 3},
#            {'date': '2018-09-28',
#             'leadStyle': 'Fell/Hung',
#             'notes': 'Practiced falling on trad gear!',
#             'pitches': 1,
#             'routeId': 106215913,
#             'style': 'Lead',
#             'tickId': 115369333,
#             'userRating': '5.9',
#             'userStars': 3},
#            {'date': '2018-09-28',
#             'leadStyle': '',
#             'notes': 'So much less painful to just TR it fast!',
#             'pitches': 1,
#             'routeId': 105947052,
#             'style': 'TR',
#             'tickId': 115369332,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2018-09-26',
#             'leadStyle': '',
#             'notes': 'Simuled in 1 pitch with Jason. 43 minutes. \n'
#                      'Gear: 8 single, 7 double, 1 micro, doubles from .5 to 3 '
#                      'plus four small cams ',
#             'pitches': 1,
#             'routeId': 105934199,
#             'style': 'Follow',
#             'tickId': 115360555,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2018-09-23',
#             'leadStyle': '',
#             'notes': 'Wide but easy!',
#             'pitches': 1,
#             'routeId': 115349846,
#             'style': 'TR',
#             'tickId': 115349947,
#             'userRating': '5.8',
#             'userStars': 3},
#            {'date': '2018-09-23',
#             'leadStyle': '',
#             'notes': 'Fun grovel!',
#             'pitches': 1,
#             'routeId': 114935623,
#             'style': 'Follow',
#             'tickId': 115349766,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-09-23',
#             'leadStyle': 'Fell/Hung',
#             'notes': 'Fell twice at crux. Didn’t finish because I hurt my '
#                      'wrist',
#             'pitches': 1,
#             'routeId': 114935630,
#             'style': 'Lead',
#             'tickId': 115349764,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-09-23',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 114935589,
#             'style': 'Lead',
#             'tickId': 115349761,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-09-18',
#             'leadStyle': '',
#             'notes': 'Sent',
#             'pitches': 1,
#             'routeId': 111714279,
#             'style': 'TR',
#             'tickId': 115333750,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-09-18',
#             'leadStyle': '',
#             'notes': 'Slipped on the last hard move',
#             'pitches': 1,
#             'routeId': 108189557,
#             'style': 'TR',
#             'tickId': 115333748,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2018-09-14',
#             'leadStyle': '',
#             'notes': 'Climbed with Jason & Ellie. Linked P1-2.',
#             'pitches': 2,
#             'routeId': 107104796,
#             'style': 'Follow',
#             'tickId': 115316448,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2018-09-11',
#             'leadStyle': '',
#             'notes': 'Sent!',
#             'pitches': 1,
#             'routeId': 105842838,
#             'style': 'TR',
#             'tickId': 115192914,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2018-09-11',
#             'leadStyle': '',
#             'notes': 'Fell once at the stemming crux at the third bolt.',
#             'pitches': 1,
#             'routeId': 105858078,
#             'style': 'TR',
#             'tickId': 115192908,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2018-09-11',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105857742,
#             'style': 'Follow',
#             'tickId': 115192907,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-09-09',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 108259166,
#             'style': 'Lead',
#             'tickId': 115181280,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2018-09-09',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 107729157,
#             'style': 'Follow',
#             'tickId': 115181279,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-09-09',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105910935,
#             'style': 'Follow',
#             'tickId': 115181277,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2018-09-09',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105910924,
#             'style': 'Lead',
#             'tickId': 115181276,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2018-09-03',
#             'leadStyle': 'Onsight',
#             'notes': 'Swapped leads with Ellie. We’d meant to link '
#                      'P2-3,4-5,6-7,8-9, but instead synced up with the party '
#                      'ahead and linked just 3-4 and 5-6. I led P1, P5-6. We '
#                      'decided against 8-9 because we didn’t have small gear',
#             'pitches': 5,
#             'routeId': 113441195,
#             'style': 'Lead',
#             'tickId': 115160920,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2018-09-02',
#             'leadStyle': 'Onsight',
#             'notes': 'Led P1,2,4 (split first pitch in half)',
#             'pitches': 4,
#             'routeId': 106104431,
#             'style': 'Lead',
#             'tickId': 115155328,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2018-09-01',
#             'leadStyle': 'Onsight',
#             'notes': '5.9 variation',
#             'pitches': 1,
#             'routeId': 108177039,
#             'style': 'Lead',
#             'tickId': 115155323,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2018-09-01',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 108177039,
#             'style': 'Lead',
#             'tickId': 115155322,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2018-09-01',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 108004982,
#             'style': 'Lead',
#             'tickId': 115155321,
#             'userRating': '5.10b',
#             'userStars': 3},
#            {'date': '2018-08-31',
#             'leadStyle': 'Redpoint',
#             'notes': 'Just climbed the first two 5.8 pitches ',
#             'pitches': 2,
#             'routeId': 105844620,
#             'style': 'Lead',
#             'tickId': 115150032,
#             'userRating': '',
#             'userStars': -1},
#            {'date': '2018-08-28',
#             'leadStyle': 'Fell/Hung',
#             'notes': 'Pinkpointed on Dylan’s pro, one take above the crux',
#             'pitches': 1,
#             'routeId': 105979738,
#             'style': 'Lead',
#             'tickId': 115141769,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-08-28',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105979760,
#             'style': 'Lead',
#             'tickId': 115141765,
#             'userRating': '5.8',
#             'userStars': 4},
#            {'date': '2018-08-28',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105979750,
#             'style': 'Lead',
#             'tickId': 115141762,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-08-27',
#             'leadStyle': '',
#             'notes': 'Swapped leads with dad. Led P1,3,5-6. (5-6 as a linked '
#                      'simul, 60m is about 7m too short!)',
#             'pitches': 6,
#             'routeId': 105857666,
#             'style': 'Lead',
#             'tickId': 115136792,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-08-26',
#             'leadStyle': 'Redpoint',
#             'notes': 'Swapped leads with mom. Led P1,4',
#             'pitches': 4,
#             'routeId': 107577227,
#             'style': 'Lead',
#             'tickId': 115143695,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-08-22',
#             'leadStyle': 'Redpoint',
#             'notes': 'Simul in 2p with Jason. Didn’t bring enough draws',
#             'pitches': 2,
#             'routeId': 107577227,
#             'style': 'Lead',
#             'tickId': 115004730,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-06-09',
#             'leadStyle': 'Onsight',
#             'notes': 'Swapped leads, led P2,5,6',
#             'pitches': 1,
#             'routeId': 105874735,
#             'style': 'Lead',
#             'tickId': 114463752,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2018-05-21',
#             'leadStyle': 'Onsight',
#             'notes': 'In two pitches. Led P2',
#             'pitches': 2,
#             'routeId': 105867008,
#             'style': 'Lead',
#             'tickId': 114393102,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2018-05-19',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105870703,
#             'style': 'Follow',
#             'tickId': 114393099,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2018-05-19',
#             'leadStyle': '',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105841118,
#             'style': 'TR',
#             'tickId': 114393096,
#             'userRating': '',
#             'userStars': 2},
#            {'date': '2018-05-17',
#             'leadStyle': 'Fell/Hung',
#             'notes': 'Fell on .5',
#             'pitches': 1,
#             'routeId': 105872323,
#             'style': 'Lead',
#             'tickId': 114393091,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-05-17',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 105874700,
#             'style': 'Lead',
#             'tickId': 114393087,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-03-28',
#             'leadStyle': '',
#             'notes': 'Pumped out twice.',
#             'pitches': 1,
#             'routeId': 107487528,
#             'style': 'TR',
#             'tickId': 114202696,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-03-28',
#             'leadStyle': '',
#             'notes': 'Pumped out several times :/',
#             'pitches': 1,
#             'routeId': 105880594,
#             'style': 'TR',
#             'tickId': 114202693,
#             'userRating': '',
#             'userStars': 3},
#            {'date': '2018-03-28',
#             'leadStyle': 'Onsight',
#             'notes': '',
#             'pitches': 1,
#             'routeId': 106128198,
#             'style': 'Lead',
#             'tickId': 114202688,
#             'userRating': '',
#             'userStars': 1},
#            {'date': '2018-03-28',
#             'leadStyle': '',
#             'notes': 'Clean',
#             'pitches': 1,
#             'routeId': 105880587,
#             'style': 'TR',
#             'tickId': 114202687,
#             'userRating': '',
#             'userStars': 4},
#            {'date': '2018-01-05',
#             'leadStyle': '',
#             'notes': '2nd attempt',
#             'pitches': 1,
#             'routeId': 106131986,
#             'style': '',
#             'tickId': 113987079,
#             'userRating': 'V1',
#             'userStars': 3},
#            {'date': '2018-01-05',
#             'leadStyle': '',
#             'notes': 'Onsight',
#             'pitches': 1,
#             'routeId': 106131992,
#             'style': '',
#             'tickId': 113987078,
#             'userRating': 'V1',
#             'userStars': 3},
#            {'date': '2018-01-05',
#             'leadStyle': '',
#             'notes': 'Onsight',
#             'pitches': 1,
#             'routeId': 106130507,
#             'style': '',
#             'tickId': 113987077,
#             'userRating': 'V0+',
#             'userStars': 3},
#            {'date': '2018-01-04',
#             'leadStyle': '',
#             'notes': 'Onsight with a boost to the hueco ',
#             'pitches': 1,
#             'routeId': 106322579,
#             'style': '',
#             'tickId': 113987080,
#             'userRating': 'V2',
#             'userStars': 2},
#            {'date': '2018-01-04',
#             'leadStyle': '',
#             'notes': 'Sent after 5-6 attempts',
#             'pitches': 1,
#             'routeId': 109903545,
#             'style': '',
#             'tickId': 113983951,
#             'userRating': 'V5',
#             'userStars': 3},
#            {'date': '2018-01-04',
#             'leadStyle': '',
#             'notes': 'Sent after a few attempts',
#             'pitches': 1,
#             'routeId': 107052779,
#             'style': '',
#             'tickId': 113983946,
#             'userRating': 'V1',
#             'userStars': 3},
#            {'date': '2018-01-04',
#             'leadStyle': '',
#             'notes': '2nd try',
#             'pitches': 1,
#             'routeId': 106094805,
#             'style': '',
#             'tickId': 113983941,
#             'userRating': 'V1',
#             'userStars': 3},
#            {'date': '2018-01-04',
#             'leadStyle': '',
#             'notes': 'Onsight',
#             'pitches': 1,
#             'routeId': 107370951,
#             'style': '',
#             'tickId': 113983938,
#             'userRating': 'V2',
#             'userStars': 3},
#            {'date': '2018-01-02',
#             'leadStyle': '',
#             'notes': 'Tried a few times, no send. Too worked',
#             'pitches': 1,
#             'routeId': 105943524,
#             'style': '',
#             'tickId': 113978618,
#             'userRating': '',
#             'userStars': -1},
#            {'date': '2018-01-02',
#             'leadStyle': '',
#             'notes': 'A bunch of attempts, no send',
#             'pitches': 1,
#             'routeId': 106052564,
#             'style': '',
#             'tickId': 113978614,
#             'userRating': '',
#             'userStars': -1},
#            {'date': '2018-01-02',
#             'leadStyle': '',
#             'notes': '2nd attempt',
#             'pitches': 1,
#             'routeId': 106126702,
#             'style': '',
#             'tickId': 113978611,
#             'userRating': 'V3',
#             'userStars': 3},
#            {'date': '2018-01-02',
#             'leadStyle': '',
#             'notes': 'Onsight',
#             'pitches': 1,
#             'routeId': 106132040,
#             'style': '',
#             'tickId': 113978607,
#             'userRating': 'V-easy',
#             'userStars': 2},
#            {'date': '2018-01-02',
#             'leadStyle': '',
#             'notes': 'Flash',
#             'pitches': 1,
#             'routeId': 106132012,
#             'style': '',
#             'tickId': 113978604,
#             'userRating': 'V2',
#             'userStars': 3},
#            {'date': '2018-01-02',
#             'leadStyle': '',
#             'notes': 'Onsight',
#             'pitches': 1,
#             'routeId': 106132031,
#             'style': '',
#             'tickId': 113978599,
#             'userRating': 'V0-',
#             'userStars': 2},
#            {'date': '2018-01-02',
#             'leadStyle': '',
#             'notes': 'Flash',
#             'pitches': 1,
#             'routeId': 106054156,
#             'style': '',
#             'tickId': 113978596,
#             'userRating': 'V2+',
#             'userStars': 3},
#            {'date': '2017-12-30',
#             'leadStyle': '',
#             'notes': 'Onsight',
#             'pitches': 1,
#             'routeId': 106322566,
#             'style': '',
#             'tickId': 113972272,
#             'userRating': 'V0',
#             'userStars': 3},
#            {'date': '2017-12-30',
#             'leadStyle': '',
#             'notes': 'Onsight',
#             'pitches': 1,
#             'routeId': 105936142,
#             'style': '',
#             'tickId': 113972271,
#             'userRating': 'V2',
#             'userStars': 3},
#            {'date': '2017-12-30',
#             'leadStyle': '',
#             'notes': 'Many attempts - worked out all the beta but didn’t send',
#             'pitches': 1,
#             'routeId': 106070944,
#             'style': '',
#             'tickId': 113972267,
#             'userRating': '',
#             'userStars': -1},
#            {'date': '2017-12-30',
#             'leadStyle': '',
#             'notes': 'Onsight',
#             'pitches': 1,
#             'routeId': 106277533,
#             'style': '',
#             'tickId': 113972265,
#             'userRating': 'V-easy',
#             'userStars': 3},
#            {'date': '2017-12-30',
#             'leadStyle': '',
#             'notes': 'Onsight',
#             'pitches': 1,
#             'routeId': 106277521,
#             'style': '',
#             'tickId': 113972263,
#             'userRating': 'V0',
#             'userStars': 2},
#            {'date': '2017-12-30',
#             'leadStyle': '',
#             'notes': 'Onsight',
#             'pitches': 1,
#             'routeId': 106277514,
#             'style': '',
#             'tickId': 113972262,
#             'userRating': 'V0',
#             'userStars': 2}],
#  'user_id': '110459813'}
